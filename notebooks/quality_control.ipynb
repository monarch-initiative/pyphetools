# %% [markdown]
# # Quality control

# %%
from pyphetools.visualization import PhenopacketIngestor
from pyphetools.validation import ContentValidator
import pyphetools
print(f"pyphetools version {pyphetools.__version__}")
# Out:
# pyphetools version 0.8.3

# %%
indir = "../../phenopacket-store/phenopackets/ANKH/"
ingestor = PhenopacketIngestor(indir=indir)
# Out:
# [pyphetools] Ingested 7 GA4GH phenopackets.

# %%
phenopacket_d = ingestor.get_phenopacket_dictionary()

# %%
for k, v in phenopacket_d.items():
    print(k,v)
# Out:
# PMID_20358596_patient_A id: "PMID_20358596_patient_A"
# subject {
#   id: "patient A"
#   time_at_last_encounter {
#     age {
#       iso8601duration: "P12Y"
#     }
#   }
# }
# phenotypic_features {
#   type {
#     id: "HP:0000316"
#     label: "Hypertelorism"
#   }
# }
# phenotypic_features {
#   type {
#     id: "HP:0001742"
#     label: "Nasal congestion"
#   }
# }
# phenotypic_features {
#   type {
#     id: "HP:0430025"
#     label: "Bilateral facial palsy"
#   }
# }
# phenotypic_features {
#   type {
#     id: "HP:0011968"
#     label: "Feeding difficulties"
#   }
# }
# phenotypic_features {
#   type {
#     id: "HP:0002795"
#     label: "Abnormal respiratory system physiology"
#   }
# }
# phenotypic_features {
#   type {
#     id: "HP:0004437"
#     label: "Cranial hyperostosis"
#   }
# }
# phenotypic_features {
#   type {
#     id: "HP:0000405"
#     label: "Conductive hearing impairment"
#   }
# }
# phenotypic_features {
#   type {
#     id: "HP:0010628"
# ...
