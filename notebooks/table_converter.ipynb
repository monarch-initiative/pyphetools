# %% [markdown]
# <h1>Generate table from collection of phenopackets</h1>
# <p>A common task for the analysis of a cohort of individuals with pathogenic variants in a given gene is to generate a table with a summary of the findings. The pyphetool package has functionality to ingest a collection of phenopakcets and to generate several different kinds of tables that may be useful for publications of supplementary material sections.</p>

# %%
import phenopackets as php
from google.protobuf.json_format import MessageToDict, MessageToJson
from google.protobuf.json_format import Parse, ParseDict
import pandas as pd
pd.set_option('display.max_colwidth', None) # show entire column contents, important!
from collections import defaultdict
import os
import sys

from phenopackets import Phenopacket
from google.protobuf.json_format import Parse
import json

import hpotk

sys.path.insert(0, os.path.abspath('../../pyphetools'))
from pyphetools.output import *

# %%
phenopacket_dir = "/Users/robinp/GIT/hrmd/notebooks/TRPM3/phenopackets"

# %%
## NOT NEEDED ANYMORE
phenopacket_paths = []
if not os.path.isdir(phenopacket_dir):
    raise ValueError(f"{phenopacket_dir} was not a directory")
for root, dirs, files in os.walk(phenopacket_dir):
    for file in files:
        if file.endswith(".json"):
            phenopacket_paths.append(os.path.join(root,file))
print(f"We extracted {len(phenopacket_paths)} GA4GH phenopackets")
# Out:
# We extracted 17 GA4GH phenopackets

# %%
ingestor = PhenopacketIngestor(indir=phenopacket_dir)

# %%
patient_d = ingestor.get_patient_dictionary()
print(f"We got {len(patient_d)} phenopackets")
# Out:
# We got 17 phenopackets

# %%
from hpotk.ontology import Ontology
from hpotk.ontology.load.obographs import load_ontology
if os.path.isfile('hpo_data/hp.json'):
    hpo_ontology = load_ontology('hpo_data/hp.json')
else:
    hpo_ontology = load_ontology('https://raw.githubusercontent.com/obophenotype/human-phenotype-ontology/master/hp.json')

# %%
focus_id = 'PMID_35146895_Individual_5'
ftab = FocusCountTable(patient_d=patient_d, focus_id=focus_id, ontology=hpo_ontology)

# %%
df = ftab.get_simple_table()

# %%
pd.set_option('display.max_rows', None)
df
# Out:
#                                              term       HP:id  focus  other  \
# 0                             Talipes equinovarus  HP:0001762      1      2
# 1                            Feeding difficulties  HP:0011968      1      0
# 2                         Intellectual disability  HP:0001249      1      2
# 3                                         Seizure  HP:0001250      1      4
# 4                                   Hip dysplasia  HP:0001385      1      0
# 5                      Global developmental delay  HP:0001263      1      5
# 6                 Intellectual disability, severe  HP:0010864      4      0
# 7                         Delayed ability to walk  HP:0031936      6      2
# 8         Delayed speech and language development  HP:0000750      6      2
# 9                               Autistic behavior  HP:0000729      4      0
# 10                        Typical absence seizure  HP:0011147      3      1
# 11                                      Hypotonia  HP:0001252      5      6
# 12                                           Tics  HP:0100033      0      3
# 13       Attention deficit hyperactivity disorder  HP:0007018      0      1
# 14                                  Hyperactivity  HP:0000752      0      1
# 15                                 Frequent falls  HP:0002359      0      1
# 16                                    Impulsivity  HP:0100710      0      1
# 17                                Sensory seeking  HP:4000079      0      1
# 18                                 Short philtrum  HP:0000322      0      1
# 19                             Hearing impairment  HP:0000365      0      1
# 20                                   Low-set ears  HP:0000369      0      1
# 21                                   Bulbous nose  HP:0000414      0      1
# 22                                     Short neck  HP:0000470      0      1
# 23                                      Amblyopia  HP:0000646      0      1
# 24                                      Synophrys  HP:0000664      0      1
# 25                                     Depression  HP:0000716      0      1
# 26                                     Dysarthria  HP:0001260      0      1
# 27                                      Dysphagia  HP:0002015      0      1
# 28                               Ventriculomegaly  HP:0002119      0      2
# 29                           Patellar dislocation  HP:0002999      0      1
# 30                             Prominent forehead  HP:0011220      0      1
# 31                                           Pain  HP:0012531      0      2
# 32  Periventricular white matter hyperintensities  HP:0030891      0      1
# 33                                Hip dislocation  HP:0002827      0      3
# 34                            Aggressive behavior  HP:0000718      0      1
# 35                               Heat intolerance  HP:0002046      0      1
# 36                        Gastroesophageal reflux  HP:0002020      0      2
# 37                                    Torticollis  HP:0000473      0      1
# 38                       Abnormal foot morphology  HP:0001760      0      1
# 39                                   Hypoglycemia  HP:0001943      0      1
# 40                                   Macrocephaly  HP:0000256      0      3
# 41                               Facial asymmetry  HP:0000324      0      1
# 42                                Frontal bossing  HP:0002007      0      3
# 43                       Delayed ability to stand  HP:0025335      0      1
# 44             EEG with generalized slow activity  HP:0010845      0      1
# 45                                       Asthenia  HP:0025406      0      1
# 46                 Bilateral tonic-clonic seizure  HP:0002069      2      0
# 47              Intellectual disability, moderate  HP:0002342      2      2
# 48                                 Polyhydramnios  HP:0001561      0      1
# 49                             Skeletal dysplasia  HP:0002652      0      1
# 50                              Maternal diabetes  HP:0009800      0      1
# 51                              Caesarian section  HP:0011410      0      1
# 52                               Poor eye contact  HP:0000817      0      1
# 53                     Cerebral visual impairment  HP:0100704      0      1
# 54                                      Nystagmus  HP:0000639      0      1
# 55                            Delayed myelination  HP:0012448      0      1
# 56                             Status epilepticus  HP:0002133      1      0
# 57                                      Exotropia  HP:0000577      0      2
# 58                                      Myoclonus  HP:0001336      0      1
# 59                                Limb hypertonia  HP:0002509      0      1
# 60                            Persistent head lag  HP:0032988      0      1
# 61                       Thin upper lip vermilion  HP:0000219      0      1
# 62                                   Widow's peak  HP:0000349      0      1
# 63                                     Short nose  HP:0003196      0      2
# 64                      Prominent nasolabial fold  HP:0005272      0      1
# 65                         High anterior hairline  HP:0009890      0      1
# 66                              Midface retrusion  HP:0011800      0      1
# 67                               Infantile spasms  HP:0012469      0      1
# 68                                  Hypertelorism  HP:0000316      0      1
# 69                                         Ptosis  HP:0000508      0      1
# 70                                      Scoliosis  HP:0002650      0      2
# 71                         Depressed nasal bridge  HP:0005280      0      1
# 72                     Hyperplasia of the maxilla  HP:0430028      0      1
# 73                       Knee flexion contracture  HP:0006380      0      1
# 74                              Tracheal stenosis  HP:0002777      0      1
# 75                      Necrotizing enterocolitis  HP:0033165      0      1
# 76                        Gray matter heterotopia  HP:0002282      0      1
# 77                                     Strabismus  HP:0000486      0      2
# 78                          Mandibular prognathia  HP:0000303      0      2
# 79                            Narrow nasal bridge  HP:0000446      0      1
# 80                                    Telecanthus  HP:0000506      0      1
# 81                    Upslanted palpebral fissure  HP:0000582      0      1
# 82                                 Tapered finger  HP:0001182      0      1
# 83                                Joint stiffness  HP:0001387      0      1
# 84                                 Trigonocephaly  HP:0000243      0      1
# 85                     Emotional hypersensitivity  HP:0041092      0      1
# 86                                         Myopia  HP:0000545      0      1
# 87                             Cerebellar atrophy  HP:0001272      0      1
# 88                                       Drooling  HP:0002307      0      1
# 89                                 Broad forehead  HP:0000337      0      1
# 90                       Posteriorly rotated ears  HP:0000358      0      1
# 91                                   Blue sclerae  HP:0000592      0      1
# 92                            Dental malocclusion  HP:0000689      0      1
# 93                               Pectus excavatum  HP:0000767      0      1
#
#             total
# 0    3/17 (17.6%)
# 1     1/17 (5.9%)
# 2    3/17 (17.6%)
# 3    5/17 (29.4%)
# 4     1/17 (5.9%)
# 5    6/17 (35.3%)
# 6    4/17 (23.5%)
# 7    8/17 (47.1%)
# 8    8/17 (47.1%)
# 9    4/17 (23.5%)
# 10   4/17 (23.5%)
# 11  11/17 (64.7%)
# 12   3/17 (17.6%)
# 13    1/17 (5.9%)
# 14    1/17 (5.9%)
# 15    1/17 (5.9%)
# 16    1/17 (5.9%)
# 17    1/17 (5.9%)
# 18    1/17 (5.9%)
# 19    1/17 (5.9%)
# 20    1/17 (5.9%)
# 21    1/17 (5.9%)
# 22    1/17 (5.9%)
# 23    1/17 (5.9%)
# 24    1/17 (5.9%)
# 25    1/17 (5.9%)
# 26    1/17 (5.9%)
# 27    1/17 (5.9%)
# 28   2/17 (11.8%)
# 29    1/17 (5.9%)
# 30    1/17 (5.9%)
# 31   2/17 (11.8%)
# 32    1/17 (5.9%)
# 33   3/17 (17.6%)
# 34    1/17 (5.9%)
# 35    1/17 (5.9%)
# 36   2/17 (11.8%)
# 37    1/17 (5.9%)
# 38    1/17 (5.9%)
# 39    1/17 (5.9%)
# 40   3/17 (17.6%)
# 41    1/17 (5.9%)
# 42   3/17 (17.6%)
# 43    1/17 (5.9%)
# 44    1/17 (5.9%)
# 45    1/17 (5.9%)
# 46   2/17 (11.8%)
# 47   4/17 (23.5%)
# 48    1/17 (5.9%)
# 49    1/17 (5.9%)
# 50    1/17 (5.9%)
# 51    1/17 (5.9%)
# 52    1/17 (5.9%)
# 53    1/17 (5.9%)
# 54    1/17 (5.9%)
# 55    1/17 (5.9%)
# 56    1/17 (5.9%)
# 57   2/17 (11.8%)
# 58    1/17 (5.9%)
# 59    1/17 (5.9%)
# 60    1/17 (5.9%)
# 61    1/17 (5.9%)
# 62    1/17 (5.9%)
# 63   2/17 (11.8%)
# 64    1/17 (5.9%)
# 65    1/17 (5.9%)
# 66    1/17 (5.9%)
# 67    1/17 (5.9%)
# 68    1/17 (5.9%)
# 69    1/17 (5.9%)
# 70   2/17 (11.8%)
# 71    1/17 (5.9%)
# 72    1/17 (5.9%)
# 73    1/17 (5.9%)
# 74    1/17 (5.9%)
# 75    1/17 (5.9%)
# 76    1/17 (5.9%)
# 77   2/17 (11.8%)
# 78   2/17 (11.8%)
# 79    1/17 (5.9%)
# 80    1/17 (5.9%)
# 81    1/17 (5.9%)
# 82    1/17 (5.9%)
# 83    1/17 (5.9%)
# 84    1/17 (5.9%)
# 85    1/17 (5.9%)
# 86    1/17 (5.9%)
# 87    1/17 (5.9%)
# 88    1/17 (5.9%)
# 89    1/17 (5.9%)
# 90    1/17 (5.9%)
# 91    1/17 (5.9%)
# 92    1/17 (5.9%)
# 93    1/17 (5.9%)
