# %% [markdown]
# <h1>Generate table from collection of phenopackets</h1>
# <p>A common task for the analysis of a cohort of individuals with pathogenic variants in a given gene is to generate a table with a summary of the findings. The pyphetool package has functionality to ingest a collection of phenopakcets and to generate several different kinds of tables that may be useful for publications of supplementary material sections.</p>

# %%
import phenopackets as php
from google.protobuf.json_format import MessageToDict, MessageToJson
from google.protobuf.json_format import Parse, ParseDict
import pandas as pd
pd.set_option('display.max_colwidth', None) # show entire column contents, important!
from collections import defaultdict
import os
import sys

from phenopackets import Phenopacket
from google.protobuf.json_format import Parse
import json

sys.path.insert(0, os.path.abspath('../../pyphetools'))
from pyphetools.output import *

# %%
phenopacket_dir = "/Users/robinp/GIT/hrmd/notebooks/TRPM3/phenopackets"

# %%
## NOT NEEDED ANYMORE
phenopacket_paths = []
if not os.path.isdir(phenopacket_dir):
    raise ValueError(f"{phenopacket_dir} was not a directory")
for root, dirs, files in os.walk(phenopacket_dir):
    for file in files:
        if file.endswith(".json"):
            phenopacket_paths.append(os.path.join(root,file))
print(f"We extracted {len(phenopacket_paths)} GA4GH phenopackets")
# Out:
# We extracted 17 GA4GH phenopackets

# %%
ingestor = PhenopacketIngestor(indir=phenopacket_dir)
# Out:
# subject_or_biosample_id: "Individual 5"
# interpretation_status: CAUSATIVE
# variant_interpretation {
#   variation_descriptor {
#     gene_context {
#       value_id: "HGNC:17992"
#       symbol: "TRPM3"
#     }
#     expressions {
#       syntax: "hgvs.c"
#       value: "NM_020952.6:c.2509G>A"
#     }
#     expressions {
#       syntax: "hgvs.g"
#       value: "NC_000009.12:g.70598463C>T"
#     }
#     vcf_record {
#       genome_assembly: "hg38"
#       chrom: "chr9"
#       pos: 70598463
#       ref: "C"
#       alt: "T"
#     }
#     molecule_context: genomic
#   }
# }
#
# subject_or_biosample_id: "1"
# interpretation_status: CAUSATIVE
# variant_interpretation {
#   variation_descriptor {
#     gene_context {
#       value_id: "HGNC:17992"
#       symbol: "TRPM3"
#     }
#     expressions {
#       syntax: "hgvs.c"
#       value: "NM_020952.6:c.2509G>A"
#     }
#     expressions {
#       syntax: "hgvs.g"
#       value: "NC_000009.12:g.70598463C>T"
#     }
#     vcf_record {
#       genome_assembly: "hg38"
#       chrom: "chr9"
#       pos: 70598463
#       ref: "C"
#       alt: "T"
#     }
#     molecule_context: genomic
#     allelic_state {
#       id: "GENO:0000135"
#       label: "heterozygous"
#     }
#   }
# }
#
# subject_or_biosample_id: "Individual 4"
# interpretation_status: CAUSATIVE
# variant_interpretation {
#   variation_descriptor {
#     gene_context {
#       value_id: "HGNC:17992"
#       symbol: "TRPM3"
#     }
#     expressions {
#       syntax: "hgvs.c"
#       value: "NM_020952.6:c.2509G>A"
#     }
#     expressions {
#       syntax: "hgvs.g"
#       value: "NC_000009.12:g.70598463C>T"
#     }
#     vcf_record {
#       genome_assembly: "hg38"
#       chrom: "chr9"
#       pos: 70598463
#       ref: "C"
#       alt: "T"
#     }
#     molecule_context: genomic
#   }
# }
#
# subject_or_biosample_id: "5-year-old girl"
# interpretation_status: CAUSATIVE
# variant_interpretation {
#   variation_descriptor {
#     gene_context {
#       value_id: "HGNC:17992"
#       symbol: "TRPM3"
#     }
#     expressions {
#       syntax: "hgvs.c"
#       value: "NM_020952.6:c.2509G>A"
#     }
#     expressions {
#       syntax: "hgvs.g"
#       value: "NC_000009.12:g.70598463C>T"
#     }
#     vcf_record {
#       genome_assembly: "hg38"
#       chrom: "chr9"
#       pos: 70598463
#       ref: "C"
#       alt: "T"
#     }
#     molecule_context: genomic
#   }
# }
#
# subject_or_biosample_id: "Individual 3"
# interpretation_status: CAUSATIVE
# variant_interpretation {
#   variation_descriptor {
#     gene_context {
#       value_id: "HGNC:17992"
#       symbol: "TRPM3"
#     }
#     expressions {
#       syntax: "hgvs.c"
#       value: "NM_020952.6:c.2509G>A"
#     }
#     expressions {
#       syntax: "hgvs.g"
#       value: "NC_000009.12:g.70598463C>T"
#     }
#     vcf_record {
#       genome_assembly: "hg38"
#       chrom: "chr9"
#       pos: 70598463
#       ref: "C"
#       alt: "T"
#     }
#     molecule_context: genomic
#   }
# }
#
# subject_or_biosample_id: "6"
# interpretation_status: CAUSATIVE
# variant_interpretation {
#   variation_descriptor {
#     gene_context {
#       value_id: "HGNC:17992"
#       symbol: "TRPM3"
#     }
#     expressions {
#       syntax: "hgvs.c"
#       value: "NM_020952.6:c.2509G>A"
#     }
#     expressions {
#       syntax: "hgvs.g"
#       value: "NC_000009.12:g.70598463C>T"
#     }
#     vcf_record {
#       genome_assembly: "hg38"
#       chrom: "chr9"
#       pos: 70598463
#       ref: "C"
#       alt: "T"
#     }
#     molecule_context: genomic
#     allelic_state {
#       id: "GENO:0000135"
#       label: "heterozygous"
#     }
#   }
# }
#
# subject_or_biosample_id: "7"
# interpretation_status: CAUSATIVE
# variant_interpretation {
#   variation_descriptor {
#     gene_context {
#       value_id: "HGNC:17992"
#       symbol: "TRPM3"
#     }
#     expressions {
#       syntax: "hgvs.c"
#       value: "NM_020952.6:c.2509G>A"
#     }
#     expressions {
#       syntax: "hgvs.g"
#       value: "NC_000009.12:g.70598463C>T"
#     }
#     vcf_record {
#       genome_assembly: "hg38"
#       chrom: "chr9"
#       pos: 70598463
#       ref: "C"
#       alt: "T"
#     }
#     molecule_context: genomic
#     allelic_state {
#       id: "GENO:0000135"
#       label: "heterozygous"
#     }
#   }
# }
#
# subject_or_biosample_id: "Individual 2"
# interpretation_status: CAUSATIVE
# variant_interpretation {
#   variation_descriptor {
#     gene_context {
#       value_id: "HGNC:17992"
#       symbol: "TRPM3"
#     }
#     expressions {
#       syntax: "hgvs.c"
#       value: "NM_020952.6:c.2509G>A"
#     }
#     expressions {
#       syntax: "hgvs.g"
#       value: "NC_000009.12:g.70598463C>T"
#     }
#     vcf_record {
#       genome_assembly: "hg38"
#       chrom: "chr9"
#       pos: 70598463
#       ref: "C"
#       alt: "T"
#     }
#     molecule_context: genomic
#   }
# }
#
# subject_or_biosample_id: "8"
# interpretation_status: CAUSATIVE
# variant_interpretation {
#   variation_descriptor {
#     gene_context {
#       value_id: "HGNC:17992"
#       symbol: "TRPM3"
#     }
#     expressions {
#       syntax: "hgvs.c"
#       value: "NM_020952.6:c.2810C>A"
#     }
#     expressions {
#       syntax: "hgvs.g"
#       value: "NC_000009.12:g.70553229G>T"
#     }
#     vcf_record {
#       genome_assembly: "hg38"
#       chrom: "chr9"
#       pos: 70553229
#       ref: "G"
#       alt: "T"
#     }
#     molecule_context: genomic
#     allelic_state {
#       id: "GENO:0000135"
#       label: "heterozygous"
#     }
#   }
# }
#
# subject_or_biosample_id: "4"
# interpretation_status: CAUSATIVE
# variant_interpretation {
#   variation_descriptor {
#     gene_context {
#       value_id: "HGNC:17992"
#       symbol: "TRPM3"
#     }
#     expressions {
#       syntax: "hgvs.c"
#       value: "NM_020952.6:c.2509G>A"
#     }
#     expressions {
#       syntax: "hgvs.g"
#       value: "NC_000009.12:g.70598463C>T"
#     }
#     vcf_record {
#       genome_assembly: "hg38"
#       chrom: "chr9"
#       pos: 70598463
#       ref: "C"
#       alt: "T"
#     }
#     molecule_context: genomic
#     allelic_state {
#       id: "GENO:0000135"
#       label: "heterozygous"
#     }
#   }
# }
#
# subject_or_biosample_id: "Individual 1"
# interpretation_status: CAUSATIVE
# variant_interpretation {
#   variation_descriptor {
#     gene_context {
#       value_id: "HGNC:17992"
#       symbol: "TRPM3"
#     }
#     expressions {
#       syntax: "hgvs.c"
#       value: "NM_020952.6:c.2509G>A"
#     }
#     expressions {
#       syntax: "hgvs.g"
#       value: "NC_000009.12:g.70598463C>T"
#     }
#     vcf_record {
#       genome_assembly: "hg38"
#       chrom: "chr9"
#       pos: 70598463
#       ref: "C"
#       alt: "T"
#     }
#     molecule_context: genomic
#   }
# }
#
# subject_or_biosample_id: "5"
# interpretation_status: CAUSATIVE
# variant_interpretation {
#   variation_descriptor {
#     gene_context {
#       value_id: "HGNC:17992"
#       symbol: "TRPM3"
#     }
#     expressions {
#       syntax: "hgvs.c"
#       value: "NM_020952.6:c.2509G>A"
#     }
#     expressions {
#       syntax: "hgvs.g"
#       value: "NC_000009.12:g.70598463C>T"
#     }
#     vcf_record {
#       genome_assembly: "hg38"
#       chrom: "chr9"
#       pos: 70598463
#       ref: "C"
#       alt: "T"
#     }
#     molecule_context: genomic
#     allelic_state {
#       id: "GENO:0000135"
#       label: "heterozygous"
#     }
#   }
# }
#
# subject_or_biosample_id: "2"
# interpretation_status: CAUSATIVE
# variant_interpretation {
#   variation_descriptor {
#     gene_context {
#       value_id: "HGNC:17992"
#       symbol: "TRPM3"
#     }
#     expressions {
#       syntax: "hgvs.c"
#       value: "NM_020952.6:c.2509G>A"
#     }
#     expressions {
#       syntax: "hgvs.g"
#       value: "NC_000009.12:g.70598463C>T"
#     }
#     vcf_record {
#       genome_assembly: "hg38"
#       chrom: "chr9"
#       pos: 70598463
#       ref: "C"
#       alt: "T"
#     }
#     molecule_context: genomic
#     allelic_state {
#       id: "GENO:0000135"
#       label: "heterozygous"
#     }
#   }
# }
#
# subject_or_biosample_id: "Individual 7"
# interpretation_status: CAUSATIVE
# variant_interpretation {
#   variation_descriptor {
#     gene_context {
#       value_id: "HGNC:17992"
#       symbol: "TRPM3"
#     }
#     expressions {
#       syntax: "hgvs.c"
#       value: "NM_020952.6:c.2509G>A"
#     }
#     expressions {
#       syntax: "hgvs.g"
#       value: "NC_000009.12:g.70598463C>T"
#     }
#     vcf_record {
#       genome_assembly: "hg38"
#       chrom: "chr9"
#       pos: 70598463
#       ref: "C"
#       alt: "T"
#     }
#     molecule_context: genomic
#   }
# }
#
# subject_or_biosample_id: "Individual 6"
# interpretation_status: CAUSATIVE
# variant_interpretation {
#   variation_descriptor {
#     gene_context {
#       value_id: "HGNC:17992"
#       symbol: "TRPM3"
#     }
#     expressions {
#       syntax: "hgvs.c"
#       value: "NM_020952.6:c.2509G>A"
#     }
#     expressions {
#       syntax: "hgvs.g"
#       value: "NC_000009.12:g.70598463C>T"
#     }
#     vcf_record {
#       genome_assembly: "hg38"
#       chrom: "chr9"
#       pos: 70598463
#       ref: "C"
#       alt: "T"
#     }
#     molecule_context: genomic
#   }
# }
#
# subject_or_biosample_id: "7-year-old patient"
# interpretation_status: CAUSATIVE
# variant_interpretation {
#   variation_descriptor {
#     gene_context {
#       value_id: "HGNC:17992"
#       symbol: "TRPM3"
#     }
#     expressions {
#       syntax: "hgvs.c"
#       value: "NM_020952.6:c.2509G>A"
#     }
#     expressions {
#       syntax: "hgvs.g"
#       value: "NC_000009.12:g.70598463C>T"
#     }
#     vcf_record {
#       genome_assembly: "hg38"
#       chrom: "chr9"
#       pos: 70598463
#       ref: "C"
#       alt: "T"
#     }
#     molecule_context: genomic
#   }
# }
#
# subject_or_biosample_id: "3"
# interpretation_status: CAUSATIVE
# variant_interpretation {
#   variation_descriptor {
#     gene_context {
#       value_id: "HGNC:17992"
#       symbol: "TRPM3"
#     }
#     expressions {
#       syntax: "hgvs.c"
#       value: "NM_020952.6:c.2509G>A"
#     }
#     expressions {
#       syntax: "hgvs.g"
#       value: "NC_000009.12:g.70598463C>T"
#     }
#     vcf_record {
#       genome_assembly: "hg38"
#       chrom: "chr9"
#       pos: 70598463
#       ref: "C"
#       alt: "T"
#     }
#     molecule_context: genomic
#     allelic_state {
#       id: "GENO:0000135"
#       label: "heterozygous"
#     }
#   }
# }

# %%
patient_d = ingestor.get_patient_dictionary()
print(f"We got {len(patient_d)} phenopackets")
# Out:
# We got 17 phenopackets
